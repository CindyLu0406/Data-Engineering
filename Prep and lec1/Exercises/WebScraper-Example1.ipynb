# %% [markdown]
# #### DATA ENGINEERING PLATFORMS (MSCA 31012)
# #### Webscraping using Python ( Example 1 )
#
# References:
# https://first-web-scraper.readthedocs.io/en/latest/
# http://web.stanford.edu/~zlotnick/TextAsData/Web_Scraping_with_Beautiful_Soup.html
# http://altitudelabs.com/blog/web-scraping-with-python-and-beautiful-soup/
#
# Installation:
# `pip install BS4`  |
# `pip install Requests`

# %%
import csv
import requests
from bs4 import BeautifulSoup
from IPython.display import HTML

# %% [markdown]
# Scraping Rules
# --------------
# - You should check a website’s Terms and Conditions before you scrape it. Be careful to read the statements about legal use of data. Usually, the data you scrape should not be used for commercial purposes.
# - Do not request data from the website too aggressively with your program (also known as spamming), as this may break the website. Make sure your program behaves in a reasonable manner (i.e. acts like a human). One request for one webpage per second is good practice.
# - The layout of a website may change from time to time, so make sure to revisit the site and rewrite your code as needed

# %%
# scrape the current Detainees of Boone County Jail from webpage into CSV
url = 'https://report.boonecountymo.org/mrcjava/servlet/SH01_MP.I00290s'
headers = {'User-Agent': "Chrome/54.0.2840.90"}
response = requests.get(url, headers=headers)
html = response.content

# %%
HTML('<iframe src=http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp width=900 height=350></iframe>')
# Out:
# <iframe src=http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp width=900 height=350></iframe>

# %%
soup = BeautifulSoup(html, "lxml")
table = soup.find('tbody', attrs={'class': 'stripe'})

# %%
tmpRow = (table.findAll('tr')[1:])
print (tmpRow)
# Out:
# [<tr class="even">
# <td class="two td_left" data-th="Last Name">ACTON</td>
# <td class="two td_left" data-th="First Name">ANTHONY</td>
# <td class="two td_left" data-th="Middle Name">SEAN</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">27</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66619&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">ARNOLD</td>
# <td class="one td_left" data-th="First Name">DANIEL</td>
# <td class="one td_left" data-th="Middle Name">JOSEPH</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">22</td>
# <td class="one td_left" data-th="City">COLUMBUIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=72830&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">ASHFORD</td>
# <td class="two td_left" data-th="First Name">NEELEY</td>
# <td class="two td_left" data-th="Middle Name">DIANA</td>
# <td class="two td_left" data-th="Sex">F</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">41</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=47913&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BAKER</td>
# <td class="one td_left" data-th="First Name">CHAD</td>
# <td class="one td_left" data-th="Middle Name">EDWARD</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">31</td>
# <td class="one td_left" data-th="City">THOMPSON</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=57253&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BALDWIN</td>
# <td class="two td_left" data-th="First Name">SAM</td>
# <td class="two td_left" data-th="Middle Name"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">27</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=57471&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BANKS</td>
# <td class="one td_left" data-th="First Name">HAROLD</td>
# <td class="one td_left" data-th="Middle Name">JOSEPH</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">17</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81801&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BARTON</td>
# <td class="two td_left" data-th="First Name">KRISTE</td>
# <td class="two td_left" data-th="Middle Name">MARIE</td>
# <td class="two td_left" data-th="Sex">F</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">34</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=39416&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BEARS</td>
# <td class="one td_left" data-th="First Name">JARED</td>
# <td class="one td_left" data-th="Middle Name">ANTHONY</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">20</td>
# <td class="one td_left" data-th="City">OAK GROVE</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80333&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BEBE</td>
# <td class="two td_left" data-th="First Name">RWAJEKARE</td>
# <td class="two td_left" data-th="Middle Name"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">40</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81866&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BECK</td>
# <td class="one td_left" data-th="First Name">JOSHUA</td>
# <td class="one td_left" data-th="Middle Name">ALEX</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">26</td>
# <td class="one td_left" data-th="City">MOBERLY</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81210&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BELL</td>
# <td class="two td_left" data-th="First Name">COLIN</td>
# <td class="two td_left" data-th="Middle Name">KEITH</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">37</td>
# <td class="two td_left" data-th="City">HALLSVILLE</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=33000&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BENNETT</td>
# <td class="one td_left" data-th="First Name">JAMES</td>
# <td class="one td_left" data-th="Middle Name">DAVID</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">45</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77429&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BENZ</td>
# <td class="two td_left" data-th="First Name">WILLIAM</td>
# <td class="two td_left" data-th="Middle Name">ERNEST</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">30</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=82166&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BERGTHOLD</td>
# <td class="one td_left" data-th="First Name">JOEY</td>
# <td class="one td_left" data-th="Middle Name">RUSSELL</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">44</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=19139&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BOBBITT</td>
# <td class="two td_left" data-th="First Name">ALLAN</td>
# <td class="two td_left" data-th="Middle Name">DALE</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">32</td>
# <td class="two td_left" data-th="City">ASHLAND</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=45005&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BOONE</td>
# <td class="one td_left" data-th="First Name">LAMONTE</td>
# <td class="one td_left" data-th="Middle Name">WESTLEY</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">26</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=62163&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BOYD</td>
# <td class="two td_left" data-th="First Name">LEE</td>
# <td class="two td_left" data-th="Middle Name">DEMAREO</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">33</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=46658&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BRADSHAW</td>
# <td class="one td_left" data-th="First Name">ADRIAN</td>
# <td class="one td_left" data-th="Middle Name">EUGENE</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">28</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=57379&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BROOKS</td>
# <td class="two td_left" data-th="First Name">JOHN</td>
# <td class="two td_left" data-th="Middle Name">RANDOLPH</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">53</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=36788&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BROWN</td>
# <td class="one td_left" data-th="First Name">BARRY</td>
# <td class="one td_left" data-th="Middle Name">RONELL</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">32</td>
# <td class="one td_left" data-th="City">FLORISSANT</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80297&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BUCKNER</td>
# <td class="two td_left" data-th="First Name">KEVIN</td>
# <td class="two td_left" data-th="Middle Name">MAURICE</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">19</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77661&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BULLOCK</td>
# <td class="one td_left" data-th="First Name">CHRISTOPHER</td>
# <td class="one td_left" data-th="Middle Name">AARON</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">47</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=18056&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BURKE</td>
# <td class="two td_left" data-th="First Name">JOHN</td>
# <td class="two td_left" data-th="Middle Name">MATTHEW</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">48</td>
# <td class="two td_left" data-th="City">HALLISVILLE</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81982&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BURKS-MATHENY</td>
# <td class="one td_left" data-th="First Name">NOAH</td>
# <td class="one td_left" data-th="Middle Name">CHRISTIANSON</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">20</td>
# <td class="one td_left" data-th="City">SPRINGFIELD</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=82546&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">CAGLE</td>
# <td class="two td_left" data-th="First Name">JAMES</td>
# <td class="two td_left" data-th="Middle Name">THOMAS</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">65</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=82275&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">CAMP</td>
# <td class="one td_left" data-th="First Name">JERRY</td>
# <td class="one td_left" data-th="Middle Name">LEE</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">33</td>
# <td class="one td_left" data-th="City">TOANO</td>
# <td class="one td_left" data-th="State">VA</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=82136&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">CAMPBELL</td>
# <td class="two td_left" data-th="First Name">OTIS</td>
# <td class="two td_left" data-th="Middle Name">LEE</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">22</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=72090&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">CANFIELD</td>
# <td class="one td_left" data-th="First Name">NATHAN</td>
# <td class="one td_left" data-th="Middle Name">EDWARD</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">37</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79636&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">CARTAGENA</td>
# <td class="two td_left" data-th="First Name">FERNANDO</td>
# <td class="two td_left" data-th="Middle Name">TITO</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">25</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=72356&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">CARTER</td>
# <td class="one td_left" data-th="First Name">LORAZ</td>
# <td class="one td_left" data-th="Middle Name">WINCE</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">33</td>
# <td class="one td_left" data-th="City">FULTON</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=38995&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">CHANEY</td>
# <td class="two td_left" data-th="First Name">CHARLIE</td>
# <td class="two td_left" data-th="Middle Name">LYNN</td>
# <td class="two td_left" data-th="Sex">F</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">30</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=62806&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">CHARTERS</td>
# <td class="one td_left" data-th="First Name">RECCO EARL</td>
# <td class="one td_left" data-th="Middle Name">DWAYNE</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">35</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=37262&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">CHEATOM</td>
# <td class="two td_left" data-th="First Name">DARIEN</td>
# <td class="two td_left" data-th="Middle Name">CAPRI</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">25</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=61765&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">CHEVIS</td>
# <td class="one td_left" data-th="First Name">JARVIS</td>
# <td class="one td_left" data-th="Middle Name">MONTRELL</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">28</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=54664&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">CLARK</td>
# <td class="two td_left" data-th="First Name">RICHARD</td>
# <td class="two td_left" data-th="Middle Name">DEREK</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">45</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=64174&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">COHEN</td>
# <td class="one td_left" data-th="First Name">NOAH</td>
# <td class="one td_left" data-th="Middle Name">QIMAR</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">24</td>
# <td class="one td_left" data-th="City">JEFFERSON CITY</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=82678&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">COIL</td>
# <td class="two td_left" data-th="First Name">JUSTIN</td>
# <td class="two td_left" data-th="Middle Name">LEE</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">41</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=39001&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">COLEMAN</td>
# <td class="one td_left" data-th="First Name">CAMERON</td>
# <td class="one td_left" data-th="Middle Name">MICHAEL LLOYD</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">22</td>
# <td class="one td_left" data-th="City">FLORISSANT</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81590&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">COLLIER</td>
# <td class="two td_left" data-th="First Name">MANDA</td>
# <td class="two td_left" data-th="Middle Name">CELESTE</td>
# <td class="two td_left" data-th="Sex">F</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">42</td>
# <td class="two td_left" data-th="City">MOBERLY</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=82517&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">COLLINS</td>
# <td class="one td_left" data-th="First Name">RENEE</td>
# <td class="one td_left" data-th="Middle Name">MICHELLE</td>
# <td class="one td_left" data-th="Sex">F</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">49</td>
# <td class="one td_left" data-th="City">ROCHEPORT</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81595&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">COMMANDER</td>
# <td class="two td_left" data-th="First Name">JAVANTE</td>
# <td class="two td_left" data-th="Middle Name">BRUCE</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">23</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=68940&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">CORNELISON</td>
# <td class="one td_left" data-th="First Name">BRIAN</td>
# <td class="one td_left" data-th="Middle Name">LEE</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">48</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=82308&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">COSEY</td>
# <td class="two td_left" data-th="First Name">JOHN</td>
# <td class="two td_left" data-th="Middle Name">KENNETH</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">18</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=82177&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">COX</td>
# <td class="one td_left" data-th="First Name">JAQUE</td>
# <td class="one td_left" data-th="Middle Name">DERON</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">29</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=68391&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">COX</td>
# <td class="two td_left" data-th="First Name">MACKENZIE</td>
# <td class="two td_left" data-th="Middle Name">PAIGE</td>
# <td class="two td_left" data-th="Sex">F</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">28</td>
# <td class="two td_left" data-th="City">FENTON</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81998&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">CRAWLEY</td>
# <td class="one td_left" data-th="First Name">EDDIE</td>
# <td class="one td_left" data-th="Middle Name">HUGHES</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">64</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=10979&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">DANIELS</td>
# <td class="two td_left" data-th="First Name">DASIA</td>
# <td class="two td_left" data-th="Middle Name">DESHAWNA</td>
# <td class="two td_left" data-th="Sex">F</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">20</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79880&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">DAVIDSON</td>
# <td class="one td_left" data-th="First Name">SARAH</td>
# <td class="one td_left" data-th="Middle Name">MARIE</td>
# <td class="one td_left" data-th="Sex">F</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">30</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=52870&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">DAVIS</td>
# <td class="two td_left" data-th="First Name">JASON</td>
# <td class="two td_left" data-th="Middle Name">WAYNE</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">37</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=43243&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="tr-paging">
# <th class="th_left paging_row bottomPaging" colspan="93">  Detainee Count: 237
#                             <div class="pagination pagination-right fixed-pagination" style="margin-left: 2em;">
# <ul>
# <li>
# <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)"><i class="fa fa-angle-double-left fa-large"> </i></a>
# </li>
# <li>
# <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)"><i class="fa fa-angle-left fa-large"> </i></a>
# </li>
# <li class="disabled">
# <a href="#">Page 1 of 5</a>
# </li>
# <li>
# <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)"><i class="fa fa-angle-right fa-large"> </i></a>
# </li>
# <li>
# <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)"><i class="fa fa-angle-double-right fa-large"> </i></a>
# </li>
# </ul>
# </div>
# </th>
# </tr>]

# %%
### Editing the code to fetch details of every record. The 'Case Number' and 'Charge Description' is Fetched for every Record.
list_of_rows = []
try:
    outfile = open("./inmates.csv", "w")
    writer = csv.writer(outfile)
    writer.writerow(["Last", "First", "Middle", "Gender", "Race", "Age", "City", "State","Case Number","Charge Description"])
    for row in table.findAll('tr'):
        list_of_cells = []
        for cell in row.findAll("td"):
            if(cell['data-th'] == ''):
                continue
            text = cell.text.replace('&nbsp;', '')
            list_of_cells.append(text)
        for anchor in row.findAll('a'):
            #href is fetched for every record and the response is parsed for every individual hit to href.
            details_href = "https://report.boonecountymo.org/mrcjava/servlet/"+anchor['href']
            details_response = requests.get(details_href)
            details_html = details_response.content
            details_soup = BeautifulSoup(details_html, "lxml")
            details_table = details_soup.find('tbody', attrs={'class': 'stripe'})
            if details_table is not None:
                details_table_tr = details_table.find('tr', attrs={"class": "detailBackground"})
                if details_table_tr is not None:
                    list_of_cells.append((details_table_tr.find('td', attrs = {'data-th' : 'CASE #'})).text)
                    list_of_cells.append((details_table_tr.find('td', attrs = {'data-th' : 'CHARGE DESCRIPTION'})).text)
        arrLength = len(list_of_cells)
        writer.writerow(list_of_cells)
finally:
    outfile.close()

# %%
# data cleaning 
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./inmates.csv')
df.head()
# Out:
#        Last    First  Middle Gender Race  Age       City State  Case Number  \
# 0  ACKERMAN  RICHARD   WAYNE      M    W   58   COLUMBIA    MO          NaN
# 1     ACTON  ANTHONY    SEAN      M    B   27   COLUMBIA    MO          NaN
# 2    ARNOLD   DANIEL  JOSEPH      M    W   22  COLUMBUIA    MO          NaN
# 3   ASHFORD   NEELEY   DIANA      F    W   41   COLUMBIA    MO          NaN
# 4     BAKER     CHAD  EDWARD      M    W   31   THOMPSON    MO          NaN
#
#    Charge Description
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
# Drop certain fields if they are not relevant for analysis
df.drop(['Race'], inplace=True, axis=1)
df.head()
# Out:
#         Last    First      Middle Gender  Age          City State  \
# 0      ACTON  ANTHONY        SEAN      M   27      COLUMBIA    MO
# 1      AHMED  MUJAHID  ABDULILLAH      M   27      COLUMBIA    MO
# 2  ALEXANDER    MIKKI        DAWN      F   42  HOLTS SUMMIT    MO
# 3      AMATO   TRAVIS      DANIEL      M   31      COLUMBIA    MO
# 4      BAKER     CHAD      EDWARD      M   31      THOMPSON    MO
#
#    Case Number  Charge Description
# 0          NaN                 NaN
# 1          NaN                 NaN
# 2          NaN                 NaN
# 3          NaN                 NaN
# 4          NaN                 NaN

# %%
# Expanding M as Male and F as Female.
gender = df['Gender']
male = gender.str.contains('M')
female = gender.str.contains('F')
df['Gender'] = np.where(male, 'Male',
                       np.where(female, 'Female',
                               gender))
df.head()
# Out:
#         Last    First      Middle  Gender  Age          City State  \
# 0      ACTON  ANTHONY        SEAN    Male   27      COLUMBIA    MO
# 1      AHMED  MUJAHID  ABDULILLAH    Male   27      COLUMBIA    MO
# 2  ALEXANDER    MIKKI        DAWN  Female   42  HOLTS SUMMIT    MO
# 3      AMATO   TRAVIS      DANIEL    Male   31      COLUMBIA    MO
# 4      BAKER     CHAD      EDWARD    Male   31      THOMPSON    MO
#
#    Case Number  Charge Description
# 0          NaN                 NaN
# 1          NaN                 NaN
# 2          NaN                 NaN
# 3          NaN                 NaN
# 4          NaN                 NaN

# %%
# Check for missing values in Case Number
df['Case Number'].isnull().values.any()
# Out:
# True

# %%
# Fill In missing values with a default value
df['Case Number'].fillna("No Case Number Available", inplace=True)
df['Charge Description'].fillna("No Description Available", inplace=True)
df.head()
# Out:
#         Last    First      Middle  Gender  Age          City State  \
# 0      ACTON  ANTHONY        SEAN    Male   27      COLUMBIA    MO
# 1      AHMED  MUJAHID  ABDULILLAH    Male   27      COLUMBIA    MO
# 2  ALEXANDER    MIKKI        DAWN  Female   42  HOLTS SUMMIT    MO
# 3      AMATO   TRAVIS      DANIEL    Male   31      COLUMBIA    MO
# 4      BAKER     CHAD      EDWARD    Male   31      THOMPSON    MO
#
#                 Case Number        Charge Description
# 0  No Case Number Available  No Description Available
# 1  No Case Number Available  No Description Available
# 2  No Case Number Available  No Description Available
# 3  No Case Number Available  No Description Available
# 4  No Case Number Available  No Description Available

# %%
# Remove whitespaces from Charge description and changing to uppercase
df['Charge Description'] = df['Charge Description'].str.strip()
df['Charge Description'] = df['Charge Description'].str.upper()
df.head()
# Out:
#         Last    First      Middle  Gender  Age          City State  \
# 0      ACTON  ANTHONY        SEAN    Male   27      COLUMBIA    MO
# 1      AHMED  MUJAHID  ABDULILLAH    Male   27      COLUMBIA    MO
# 2  ALEXANDER    MIKKI        DAWN  Female   42  HOLTS SUMMIT    MO
# 3      AMATO   TRAVIS      DANIEL    Male   31      COLUMBIA    MO
# 4      BAKER     CHAD      EDWARD    Male   31      THOMPSON    MO
#
#                 Case Number        Charge Description
# 0  No Case Number Available  NO DESCRIPTION AVAILABLE
# 1  No Case Number Available  NO DESCRIPTION AVAILABLE
# 2  No Case Number Available  NO DESCRIPTION AVAILABLE
# 3  No Case Number Available  NO DESCRIPTION AVAILABLE
# 4  No Case Number Available  NO DESCRIPTION AVAILABLE

# %%
# save final results
df.to_csv("./cleaninmates.csv")
